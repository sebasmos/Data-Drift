# %%
# !pip install openpyxl
# !pip install pandas-gbq -U
# !pip install tableone
# !pip install pydata-google-auth
# !pip install python-docx
# !pip install --upgrade shap numpy
# Out:
# Requirement already satisfied: openpyxl in /Users/lnazer/anaconda3/lib/python3.11/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: pandas-gbq in /Users/lnazer/anaconda3/lib/python3.11/site-packages (0.26.0)
# Requirement already satisfied: setuptools in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas-gbq) (68.0.0)
# Requirement already satisfied: db-dtypes<2.0.0,>=1.0.4 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas-gbq) (1.2.0)
# Requirement already satisfied: numpy>=1.18.1 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas-gbq) (1.26.4)
# Requirement already satisfied: pandas>=1.1.4 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas-gbq) (2.2.2)
# Requirement already satisfied: pyarrow>=4.0.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas-gbq) (16.1.0)
# Requirement already satisfied: pydata-google-auth>=1.5.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas-gbq) (1.8.2)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.10.2 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas-gbq) (2.16.2)
# Requirement already satisfied: google-auth>=2.13.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas-gbq) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib>=0.7.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas-gbq) (1.2.0)
# Requirement already satisfied: google-cloud-bigquery<4.0.0dev,>=3.4.2 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas-gbq) (3.17.1)
# Requirement already satisfied: packaging>=22.0.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas-gbq) (24.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.10.2->pandas-gbq) (1.62.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.10.2->pandas-gbq) (4.25.2)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.10.2->pandas-gbq) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from google-auth>=2.13.0->pandas-gbq) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from google-auth>=2.13.0->pandas-gbq) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from google-auth>=2.13.0->pandas-gbq) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from google-auth-oauthlib>=0.7.0->pandas-gbq) (1.3.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from google-cloud-bigquery<4.0.0dev,>=3.4.2->pandas-gbq) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from google-cloud-bigquery<4.0.0dev,>=3.4.2->pandas-gbq) (2.7.0)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from google-cloud-bigquery<4.0.0dev,>=3.4.2->pandas-gbq) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas>=1.1.4->pandas-gbq) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas>=1.1.4->pandas-gbq) (2023.3)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery<4.0.0dev,>=3.4.2->pandas-gbq) (1.5.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.13.0->pandas-gbq) (0.4.8)
# Requirement already satisfied: six>=1.5 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery<4.0.0dev,>=3.4.2->pandas-gbq) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core<3.0.0dev,>=2.10.2->pandas-gbq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core<3.0.0dev,>=2.10.2->pandas-gbq) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core<3.0.0dev,>=2.10.2->pandas-gbq) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core<3.0.0dev,>=2.10.2->pandas-gbq) (2024.8.30)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.0->pandas-gbq) (3.2.2)
# Requirement already satisfied: tableone in /Users/lnazer/anaconda3/lib/python3.11/site-packages (0.8.0)
# Requirement already satisfied: jinja2 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from tableone) (3.1.4)
# Requirement already satisfied: numpy in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from tableone) (1.26.4)
# Requirement already satisfied: openpyxl in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from tableone) (3.1.5)
# Requirement already satisfied: pandas in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from tableone) (2.2.2)
# Requirement already satisfied: scipy in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from tableone) (1.13.1)
# Requirement already satisfied: statsmodels in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from tableone) (0.14.2)
# Requirement already satisfied: tabulate in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from tableone) (0.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from jinja2->tableone) (2.1.3)
# Requirement already satisfied: et-xmlfile in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from openpyxl->tableone) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas->tableone) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas->tableone) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas->tableone) (2023.3)
# Requirement already satisfied: patsy>=0.5.6 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from statsmodels->tableone) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from statsmodels->tableone) (24.1)
# Requirement already satisfied: six in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from patsy>=0.5.6->statsmodels->tableone) (1.16.0)
# Requirement already satisfied: pydata-google-auth in /Users/lnazer/anaconda3/lib/python3.11/site-packages (1.8.2)
# Requirement already satisfied: setuptools in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pydata-google-auth) (68.0.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pydata-google-auth) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pydata-google-auth) (1.2.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from google-auth<3.0dev,>=1.25.0->pydata-google-auth) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from google-auth<3.0dev,>=1.25.0->pydata-google-auth) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from google-auth<3.0dev,>=1.25.0->pydata-google-auth) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from google-auth-oauthlib>=0.4.0->pydata-google-auth) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->pydata-google-auth) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.0->pydata-google-auth) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.0->pydata-google-auth) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.0->pydata-google-auth) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.0->pydata-google-auth) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.0->pydata-google-auth) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.0->pydata-google-auth) (2024.8.30)
# Requirement already satisfied: python-docx in /Users/lnazer/anaconda3/lib/python3.11/site-packages (1.1.2)
# Requirement already satisfied: lxml>=3.1.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from python-docx) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from python-docx) (4.11.0)
# Requirement already satisfied: shap in /Users/lnazer/anaconda3/lib/python3.11/site-packages (0.46.0)
# Requirement already satisfied: numpy in /Users/lnazer/anaconda3/lib/python3.11/site-packages (1.26.4)
# Collecting numpy
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/59/14/645887347124e101d983e1daf95b48dc3e136bf8525cb4257bf9eab1b768/numpy-2.2.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading numpy-2.2.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 523.2 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scipy in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from shap) (1.5.2)
# Requirement already satisfied: pandas in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from shap) (4.66.5)
# Requirement already satisfied: packaging>20.9 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from shap) (24.1)
# Requirement already satisfied: slicer==0.0.8 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from shap) (3.0.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from numba->shap) (0.43.0)
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/8b/cf/034500fb83041aa0286e0fb16e7c76e5c8b67c0711bb6e9e9737a717d5fe/numpy-2.0.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading numpy-2.0.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from pandas->shap) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in /Users/lnazer/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)
# Downloading numpy-2.0.2-cp311-cp311-macosx_10_9_x86_64.whl (21.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.2/21.2 MB 8.5 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.0.2 which is incompatible.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.0.2 which is incompatible.
# Successfully installed numpy-2.0.2

# %%
import pandas as pd
from tableone import TableOne
import sklearn as sk
from xgboost import XGBClassifier, XGBRegressor
import numpy as np
from scipy.stats import ttest_ind
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, average_precision_score, accuracy_score, recall_score, precision_score, f1_score, balanced_accuracy_score
from sklearn.metrics import r2_score, mean_absolute_error
from fairlearn.metrics import equalized_odds_ratio, demographic_parity_ratio
from sklearn.utils.class_weight import compute_class_weight
from tqdm import tqdm
import warnings
import shap
from tableone import tableone
from matplotlib import pyplot as plt
from lightgbm import LGBMClassifier
import pydata_google_auth
import seaborn as sns
from imblearn.pipeline import Pipeline
import pandas_gbq


warnings.filterwarnings("ignore")

# %%
credentials = pydata_google_auth.get_user_credentials(['https://www.googleapis.com/auth/cloud-platform'],)
project = 'capacheiv'
pandas_gbq.context.credentials = credentials

# %%
#importing data from eICU 1, 2015 and 2016
query = ""
for fn in ['icustays', 'apache_vars', 'apache_pt_results', 'sepsis']:
    with open('sql_copy/'+fn+'.sql', 'r') as file:
        query += file.read()
query += "select * from sepsis"
project = 'capacheiv'

gbq_data_15_16 = pd.read_gbq(query, dialect='standard', project_id=project)

# %%
#importing data from eICU 2, 2017 until 2021
query = ""
for fn in ['icustays', 'apache_vars', 'apache_pt_results', 'sepsis']:
    with open('sql_new/'+fn+'.sql', 'r') as file:
        query += file.read()
query += "select * from sepsis"
project = 'capacheiv'

gbq_data_17_21 = pd.read_gbq(query, dialect='standard', project_id=project)

# %%
df_old = gbq_data_15_16
df_new = gbq_data_17_21

# %%
df_new_no_duplicates = df_new[~df_new['uniquepid'].isin(df_old['uniquepid'])]

# %%
df_pre_clean = pd.concat([df_old, df_new_no_duplicates], axis=0, ignore_index=True)

# %%
df_first_admission = df_pre_clean[df_pre_clean['HOSP_NUM'] == 1]

# %%
df = df_first_admission[df_first_admission['has_sepsis'] == 1]

# %%
print(f"full: {len(df_new_no_duplicates)}\n"
      f"first_admissions: {len(df_first_admission)}\n"
      f"sepsis: {len(df)}\n")
# Out:
# full: 100047
# first_admissions: 156921
# sepsis: 27141
